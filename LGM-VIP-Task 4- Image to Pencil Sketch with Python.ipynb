# %%
pip install opencv-contrib-python-headless
# Out:
# Requirement already satisfied: opencv-contrib-python-headless in c:\users\admin\anaconda3\lib\site-packages (4.5.4.58)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\admin\anaconda3\lib\site-packages (from opencv-contrib-python-headless) (1.19.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image=cv2.imread("Flower.jpeg")

# %%
im_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(im_rgb)
plt.title("Original Image")
plt.axis("off");

# %%
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(10,6))
plt.imshow(gray_image,cmap="gray")
plt.title("GrayScale Image")
plt.axis("off");

# %%
inverted_image=255-gray_image
plt.figure(figsize=(10,6))
plt.imshow(inverted_image,cmap="gray")
plt.title("Inverted Image")
plt.axis("off");

# %%
blur=cv2.GaussianBlur(inverted_image,(21,21),0)
plt.figure(figsize=(10,6))
plt.imshow(blur,cmap="gray")
plt.title("Smoothen Image")
plt.axis("off");

# %%
sketch=cv2.divide(gray_image,255-blur,scale=255)
plt.figure(figsize=(10,6))
plt.imshow(sketch,cmap="gray")
plt.title("Final Sketch Image")
plt.axis("off");
